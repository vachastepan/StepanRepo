# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## ARES XML Processing Functions & Common params

# %%
from lxml import etree as ET
import pandas as pd
import re

# input parameters
xml_namespaces = {'are': 'http://wwwinfo.mfcr.cz/ares/xml_doc/schemas/ares/ares_answer_or/v_1.0.2', 
              'dtt': 'http://wwwinfo.mfcr.cz/ares/xml_doc/schemas/ares/ares_datatypes/v_1.0.2',
              'udt': 'http://wwwinfo.mfcr.cz/ares/xml_doc/schemas/uvis_datatypes/v_1.0.1',
              'xsi': 'http://www.w3.org/2001/XMLSchema-instance'
             }
xml_data = ET.parse("darv_or.xml")

# Check if tag/attribute @ exists and return its value
def set_tag_value(attr_xpath, elem, xml_namespaces):
    if re.search('@',attr_xpath) is not None and elem.xpath(attr_xpath,namespaces = xml_namespaces) != []:# check for @ for attributes
        tag_value = elem.xpath(attr_xpath,namespaces = xml_namespaces)[0]
    elif elem.xpath(attr_xpath,namespaces = xml_namespaces) != []:
            tag_value = elem.xpath(attr_xpath,namespaces = xml_namespaces)[0].text
    else:
        tag_value = None
    return tag_value

# Iterate elements under parent tag and get element tag/attr values, static key values are assigned as well
def populate_table (xml_data,parent_tag, table_columns):
    table_columns_pd = pd.DataFrame(table_columns,columns =['tag','xpath','type'])
    iter_tag_values = []
    key_values = []
    for item in table_columns:
        if item[2] == 'S':
            key_values.append(set_tag_value(item[1],xml_data, xml_namespaces))
    if parent_tag:
        for elem in parent_tag:
            tag_values = []
            for item in table_columns:
                if item[2] == 'I':
                    tag_values.append(set_tag_value(item[1],elem, xml_namespaces)) 
            tag_values = key_values + tag_values
            iter_tag_values.append(tag_values)
    else:
        iter_tag_values.insert(0,key_values)
    table_pd = pd.DataFrame(iter_tag_values, columns=table_columns_pd['tag'].tolist())
    return table_pd

# %% [markdown]
# ### zakladni_udaje

# %%
basic_info_table_columns = [
    # Vypis Vypis_OR/Uvod
    ['Aktualizace_DB','./are:Odpoved/dtt:Vypis_OR/dtt:Uvod/dtt:Aktualizace_DB','S'],
    ['Datum_vypisu','./are:Odpoved/dtt:Vypis_OR/dtt:Uvod/dtt:Datum_vypisu','S'],
    # Zakladni_udaje
    ['ICO','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:ICO','S'],
    ['Stav_subjektu','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Stav/dtt:Stav_subjektu','S'],
    ['Konkurz','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Stav/dtt:Konkurz/dtt:Kod','S'],
    ['Vyrovnani','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Stav/dtt:Vyrovnani/dtt:Kod','S'],
    ['Zamitnuti','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Stav/dtt:Zamitnuti/dtt:Kod','S'],
    ['Likvidace','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Stav/dtt:Likvidace/dtt:Kod','S'],
    ['Datum_zapisu_OR','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Datum_zapisu_OR','S'],
    # Registrace
    
    ['Soud_Kod','./are:Odpoved/dtt:Vypis_OR/dtt:Registrace/dtt:Spisova_znacka/dtt:Soud/dtt:Kod','S'],
    ['Soud_Text','./are:Odpoved/dtt:Vypis_OR/dtt:Registrace/dtt:Spisova_znacka/dtt:Soud/dtt:Text','S'],
    ['Oddil_vlozka','./are:Odpoved/dtt:Vypis_OR/dtt:Registrace/dtt:Spisova_znacka/dtt:Oddil_vlozka','S'],
    
    # Pravni_forma_OR
    ['Kod_PF','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Pravni_forma_OR/dtt:Kod_PF','S'],
    ['Nazev_PF','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Pravni_forma_OR/dtt:Nazev_PF','S'],
    ['PF_osoba','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Pravni_forma_OR/dtt:PF_osoba','S'],
    ['TZU_osoba','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Pravni_forma_OR/dtt:TZU_osoba','S'],
    
]
populate_table(xml_data,None,basic_info_table_columns)
# Out:
#   Aktualizace_DB Datum_vypisu       ICO Stav_subjektu Konkurz Vyrovnani  \
# 0     2018-08-22   2018-08-23  63275635       Aktivní       0         0
#
#   Zamitnuti Likvidace Datum_zapisu_OR Soud_Kod  \
# 0         0         0      1995-08-01        3
#
#                              Soud_Text  Oddil_vlozka Kod_PF  \
# 0  Krajský soud v Českých Budějovicích  B        698    121
#
#              Nazev_PF PF_osoba TZU_osoba
# 0  Akciová společnost        P  Tuzemská

# %% [markdown]
# ### obchodni_firma

# %%
company_name_table_columns = [
    ['ICO','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:ICO','S'],
    ['dod','./@dod','I'],
    ['ddo','./@ddo','I'],
    ['Obchodni_firma','.','I']
]
company_name_parent_tag = xml_data.xpath('./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Obchodni_firma',namespaces = xml_namespaces)
populate_table(xml_data,company_name_parent_tag,company_name_table_columns)
# Out:
#         ICO         dod         ddo                Obchodni_firma
# 0  63275635  2006-06-30        None                  MADETA a. s.
# 1  63275635  2005-07-04  2006-06-30            MADETA Group a. s.
# 2  63275635  1995-08-01  2005-07-04  JIHOMILK, akciová společnost

# %% [markdown]
# ### sidlo

# %%
# S = static record key from ancestor tag (static), I = iterative records under parent_tag 
headquarters_table_columns = [
    ['ICO','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:ICO','S'],
    ['dod','./@dod','I'],
    ['ddo','./@ddo','I'],
    ['ID_adresy','./dtt:ID_adresy','I'],
    ['Kod_statu','./dtt:Kod_statu','I'],
    ['Nazev_statu','./dtt:Nazev_statu','I'],
    ['Nazev_okresu','./dtt:Nazev_okresu','I'],
    ['Nazev_obce','./dtt:Nazev_obce','I'],
    ['Nazev_casti_obce','./dtt:Nazev_casti_obce','I'],
    ['Nazev_ulice','./dtt:Nazev_ulice','I'],
    ['Cislo_domovni','./dtt:Cislo_domovni','I'],
    ['Typ_cislo_domovni','./dtt:Typ_cislo_domovni','I'],
    ['Cislo_orientacni','./dtt:Cislo_orientacni','I'],
    ['PSC','./dtt:PSC','I'],
    ['Cislo_do_adresy','./dtt:Cislo_do_adresy','I']
                      ]
headquarters_parent_tag = xml_data.xpath('./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:Sidlo',namespaces = xml_namespaces)
populate_table(xml_data,headquarters_parent_tag,headquarters_table_columns)
# Out:
#         ICO         dod         ddo ID_adresy Kod_statu      Nazev_statu  \
# 0  63275635  2017-11-23        None  29643147       203  Česká republika
# 1  63275635  2016-12-07  2017-11-23  29643145       203  Česká republika
# 2  63275635  2002-08-14  2016-12-07  29643143       203  Česká republika
# 3  63275635  1995-08-01  2002-08-14  29643141       203  Česká republika
#
#        Nazev_okresu        Nazev_obce    Nazev_casti_obce      Nazev_ulice  \
# 0  České Budějovice  České Budějovice  České Budějovice 4  Rudolfovská tř.
# 1  České Budějovice  České Budějovice  České Budějovice 4  Rudolfovská tř.
# 2  České Budějovice  České Budějovice                None      Rudolfovská
# 3              None  České Budějovice                None      Rudolfovská
#
#   Cislo_domovni Typ_cislo_domovni Cislo_orientacni    PSC Cislo_do_adresy
# 0           246                 1               83  37001            None
# 1           246                 1               83  37001            None
# 2          None              None             None  37050          246/83
# 3          None              None             None  37050              83

# %% [markdown]
# ### predmet_podnikani
# __TODO__:
#
# Rozmyslet jestli brat i ostatni cinnosti (ucel nadace atp.),
#
# texty obsahuji \n nutno strip, nebo replace

# %%
cinnosti_table_columns = [
    ['ICO','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:ICO','S'],
    ['dod','./@dod','I'],
    ['ddo','./@ddo','I'],
    ['predmet_podnikani','.','I']
]
cinnosti_parent_tag = xml_data.xpath('./are:Odpoved/dtt:Vypis_OR/dtt:Cinnosti/dtt:Predmet_podnikani/dtt:Text',namespaces = xml_namespaces)
populate_table(xml_data,cinnosti_parent_tag,cinnosti_table_columns)
# Out:
#          ICO         dod         ddo  \
# 0   63275635  2014-08-06        None
# 1   63275635  2011-11-10        None
# 2   63275635  2011-11-10        None
# 3   63275635  2009-03-06        None
# 4   63275635  2009-03-06        None
# 5   63275635  2009-03-06        None
# 6   63275635  2008-01-22  2009-03-06
# 7   63275635  2007-10-11  2015-04-18
# 8   63275635  2007-10-11  2015-04-18
# 9   63275635  2007-10-11  2015-04-18
# 10  63275635  2006-06-30        None
# 11  63275635  2006-06-30        None
# 12  63275635  2006-06-30        None
# 13  63275635  2006-06-30        None
# 14  63275635  2006-06-30        None
# 15  63275635  2006-06-30        None
# 16  63275635  2006-06-30        None
# 17  63275635  2006-06-30        None
# 18  63275635  2006-06-30        None
# 19  63275635  2006-06-30        None
# 20  63275635  2006-06-30  2009-03-06
# 21  63275635  2006-06-30  2009-03-06
# 22  63275635  2006-06-30  2009-03-06
# 23  63275635  2006-06-30  2009-03-06
# 24  63275635  2006-06-30  2009-03-06
# 25  63275635  2005-02-01  2009-03-06
# 26  63275635  2005-02-01  2009-03-06
# 27  63275635  2005-02-01  2009-03-06
# 28  63275635  2005-02-01  2009-03-06
# 29  63275635  2005-02-01  2009-03-06
# 30  63275635  2005-02-01  2009-03-06
# 31  63275635  1998-07-01  2009-03-06
# 32  63275635  1998-07-01  2009-03-06
# 33  63275635  1995-08-01  2009-03-06
# 34  63275635  1995-08-01  2009-03-06
#
#                                     predmet_podnikani
# 0   \nprodej kvasného lihu, konzumního lihu a liho...
# 1                       \nopravy silničních vozidel\n
# 2                  \nklempířství a oprava karoserií\n
# 3                      \nzámečnictví, nástrojářství\n
# 4   \nvýroba, obchod a služby neuvedené v přílohác...
# 5   \nvýroba, instalace, opravy elektrických stroj...
# 6           \ntestování, měření, analýzy a kontroly\n
# 7   \nkoupě za účelem jeho dalšího prodeje a prodej\n
# 8                                     \nvelkoobchod\n
# 9                     \nzprostředkovatelská činnost\n
# 10                              \nhostinská činnost\n
# 11                  \nvýroba kosmetických přípravků\n
# 12             \nsilniční motorová doprava nákladní\n
# 13                                   \nmlékárenství\n
# 14       \nrevize vyhrazených elektrických zařízení\n
# 15                 \nprojektová činnost ve výstavbě\n
# 16  \nrevize a zkoušky vyhrazených tlakových zaříz...
# 17                           \npronájem nemovitostí\n
# 18  \nprovozování čerpacích stanic s palivy a mazi...
# 19                          \nvýroby a rozvod tepla\n
# 20                                    \nvelkoobchod\n
# 21                        \nzprostředkování obchodu\n
# 22                                    \nzámečnictví\n
# 23                    \npronájem průmyslového zboží\n
# 24                    \nzastupování v celním řízení\n
# 25   \nzpracování dat, služby databank, správa sítí\n
# 26  \nčinnost podnikatelských, finančních, organiz...
# 27                               \nubytovací služby\n
# 28                   \nreklamní činnost a marketing\n
# 29  \nvýroba, instalace a opravy elektronických za...
# 30  \nposkytování software a poradenství v oblasti...
# 31                            \nvymáhání pohledávek\n
# 32                             \nporadenská činnost\n
# 33  \nkoupě zboží za účelem jeho dalšího prodeje a...
# 34                    \nzprostředkovatelská činnost\n

# %% [markdown]
# ### statutarni_organ
# __TODO:__ zkontrolovat v profilingu, existenci FO bez bydliste v takovem pripade jeste iterovat pres FO a nasledne spojit DFs pres unique

# %%
statutory_table_columns = [
    ['ICO','./are:Odpoved/dtt:Vypis_OR/dtt:Zakladni_udaje/dtt:ICO','S'],
    ['Titul_pred','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Titul_pred','I'],
    ['Jmeno','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Jmeno','I'],
    ['Prijmeni','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Prijmeni','I'],
    ['Titul_za','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Titul_za','I'],
    ['Datum_narozeni','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Datum_narozeni','I'],
    ['Rodne_cislo','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Rodne_cislo','I'],
    ['Osoba_textem','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Osoba_textem','I'],
    ['Bydliste_dod','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/@dod','I'],
    ['Bydliste_ddo','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/@ddo','I'],
    ['ID_adresy','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:ID_adresy','I'],
    ['Kod_statu','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Kod_statu','I'],
    ['Nazev_statu','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Nazev_statu','I'],
    ['Nazev_okresu','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Nazev_okresu','I'],
    ['Nazev_obce','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Nazev_obce','I'],
    ['Nazev_casti_obce','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Nazev_casti_obce','I'],
    ['Nazev_ulice','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Nazev_ulice','I'],
    ['Cislo_domovni','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Cislo_domovni','I'],
    ['Typ_cislo_domovni','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Typ_cislo_domovni','I'],
    ['Cislo_orientacni','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Cislo_orientacni','I'],
    ['PSC','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:PSC','I'],
    ['Cislo_do_adresy','./dtt:Clen/dtt:Fyzicka_osoba/dtt:Bydliste/dtt:Cislo_do_adresy','I']
]
statutory_parent_tag = xml_data.xpath('./are:Odpoved/dtt:Vypis_OR/dtt:Statutarni_organ/dtt:Clen_SO',namespaces = xml_namespaces)
data = populate_table(xml_data,statutory_parent_tag,statutory_table_columns)
data.head(100)
# Out:
#          ICO Titul_pred      Jmeno  Prijmeni Titul_za Datum_narozeni  \
# 0   63275635       Ing.      PAVEL    Tester     None     1984-12-02
# 1   63275635       Ing.      PAVEL  BURYÁNEK     None     1984-12-02
# 2   63275635       Ing.      MILAN     TEPLÝ     None     1949-03-26
# 3   63275635       Ing.       PETR     PAYER     None     1976-07-17
# 4   63275635       Ing.        JAN     TEPLÝ     None     1980-03-15
# 5   63275635       Ing.      PAVEL  BURYÁNEK     None     1984-12-02
# 6   63275635       Ing.      PAVEL  BURYÁNEK     None     1984-12-02
# 7   63275635       Ing.       PETR     PAYER     None     1976-07-17
# 8   63275635       Ing.        JAN     TEPLÝ     None     1980-03-15
# 41  Česká republika   České Budějovice    České Budějovice
# 42  Česká republika               None    České Budějovice
# 43  Česká republika               None             Praha 5
# 44  Česká republika               None    České Budějovice
#
#          Nazev_casti_obce        Nazev_ulice Cislo_domovni Typ_cislo_domovni  \
# 0                    None               None          None              None
# 1   Veselí nad Lužnicí II        Na Pasekách           948                 1
# 2      České Budějovice 2        České Vrbné          2307                 1
# 3      České Budějovice 3           Nerudova           904                 1
# 4      České Budějovice 2        České Vrbné          2307                 1
# 5    Veselí nad Lužnicí I         A. Jiráska           349                 1
# 6    Veselí nad Lužnicí I         A. Jiráska           349                 1
# 7      České Budějovice 3           Nerudova           904                 1
# 8      České Budějovice 2        České Vrbné          2307                 1
# 9      České Budějovice 2        České Vrbné          2307                 1
# 10     České Budějovice 2          Třebínská          1696                 1
# 11                   None         Družstevní          None              None
# 12                   None          K. Štěcha          None              None
# 13     České Budějovice 2        České Vrbné          2307                 1
# 14                   None      Jiřího Franka          None              None
# 15                   None        České Vrbné          None              None
# 16                   None           Nerudova          None              None
# 17                   None           Lhenická          None              None
# 18                   None         Jeronýmova          None              None
# 19                   None           Na Konci          None              None
# 20                   None        České Vrbné          None              None
# 21                   None       Karla Štěcha          None              None
# 22                   None       Karla Štěcha          None              None
# 23                   None  Antonína Slavíčka          None              None
# 24                   None        Branišovská          None              None
# 25                   None        Branišovská          None              None
# 26                   None        České Vrbné          None              None
# 27                   None           28.října          None              None
# 28                   None           28.října          None              None
# 29                   None        Za nádražím          None              None
# 30                   None           Lhenická          None              None
# 31                   None         B. Němcové          None              None
# 32                   None           K vilkám          None              None
# 33                   None          Pod lesem          None              None
# 34                   None           Lhenická          None              None
# 35                   None           Lhenická          None              None
# 36                   None      Roháče z Dubí          None              None
# 37                   None       Gen. Svobody          None              None
# 38                   None         Bezdrevská          None              None
# 39                   None               None          None              None
# 40                   None        Na Březince          None              None
# 41                   None          Puklicova          None              None
# 42                   None          Boreckého          None              None
# 43                   None        Na Březince          None              None
# 44                   None         Bezdrevská          None              None
#
#    Cislo_orientacni    PSC Cislo_do_adresy
# 0              None   None            None
# 1              None  39181            None
# 2              None  37011            None
# 3                66  37004            None
# 4              None  37011            None
# 5              None  39181            None
# 6              None  39181            None
# 7                66  37004            None
# 8              None  37011            None
# 9              None  37011            None
# 10                3  37005            None
# 11             None  25751             467
# 12                8  37005            None
# 13             None  37011            None
# 14             None  25601            1728
# 15             None  37011            2307
# 16             None  37004          848/41
# 17             None   None               3
# 18             None  39002         1782/20
# 19             None  25245             263
# 20             None   None            2307
# 21             None  37005               8
# 22             None  37005               8
# 23             None  37005              24
# 24             None  37005              54
# 25             None  37005              54
# 26             None   None            2307
# 27             None  37001         1480/11
# 28             None  37001          1480/1
# 29             None  38101             216
# 30             None   None               3
# 31             None  74101              20
# 32             None  37705        829/ III
# 33             None  37371            None
# 34             None   None               3
# 35             None   None               3
# 36             None  37001              13
# 37             None  37001              51
# 38             None  37011               7
# 39             None   None            None
# 40             None   None         21/1370
# 41             None   None              21
# 42             None  37011              23
# 43             None   None         21/1370
# 44             None  37011               7
#
# [45 rows x 22 columns]
